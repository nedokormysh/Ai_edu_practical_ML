# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_Ai_edu_practical_ML/blob/week_6_feature_extraction/DataPrep_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Обработка признаков

# %% [markdown]
# В этом домашнем задании вы будете решать задачу предсказания стоимости автомобилей по их различным характеристикам.

# %%
import pandas as pd

RANDOM_STATE = 42

# %%
df = pd.read_csv("https://raw.githubusercontent.com/evgpat/edu_stepik_practical_ml/main/datasets/cars_prices.csv", decimal='.')

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Описание некоторых признаков
#
# `symboling` - rating corresponds to the degree to which the auto is more risky than its price indicates (+3 more risk and -3 is pretty safe)
# `make` - car types (i.e. car brand)
# `fuel-type` - types of fuel (gas or diesel)
# `aspiration` - engine aspiration (standard or turbo)
# `num-of-doors` - numbers of doors (two or four)
# `body-style` - car body style (sedan or hachback)
# `drive-wheels` - which types of drive wheel (forward-fwd, reversed-rwd)
# `engine-location` - engine mounted location (front or back)
# `wheel-base` - расстояние между осями передних и задних колес
# `length` - car lenght
# `weight` - car weight
# `width` - car width
# `height` - car height

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %% [markdown]
# ## Заполнение пропусков

# %% [markdown]
# Пропуски в этом датасете обозначены как `?`

# %%
for c in df.columns:
    print(c, len(df[df[c] == '?']))
# Out:
# symboling 0
# normalized-losses 41
# make 0
# fuel-type 0
# aspiration 0
# num-of-doors 2
# body-style 0
# drive-wheels 0
# engine-location 0
# wheel-base 0
# length 0
# width 0
# height 0
# curb-weight 0
# engine-type 0
# num-of-cylinders 0
# engine-size 0
# fuel-system 0
# bore 4
# stroke 4
# compression-ratio 0
# horsepower 2
# peak-rpm 2
# city-mpg 0
# highway-mpg 0
# price 4

# %% [markdown]
# Удалите строки, для которых неизвестно значение price, так как это целевая переменная.

# %%
# df = df[df['price'].notna()]
# df['price'].dropna(inplace=True)

# %%
import numpy as np

# %%
df = df.replace('?', np.nan)

# %%
# df['price'].dropna(inplace=True)

# %%
df = df[df['price'].notna()]

# %% [markdown]
# ## Вопрос для Quiz
#
# Сколько строк осталось в данных?

# %%
# your code here
df.shape
# Out:
# (201, 26)

# %% [markdown]
# Заполните средним значением пропуски в столбцах для числовых признаков и самым популярным значением для категориальных признаков
# * `num-of-doors`
# * `bore`
# * `stroke`
# * `horsepower`
# * `peak-rpm`

# %%
# your code here
cat_lst = ['num-of-doors', 'bore', 'stroke', 'horsepower', 'peak-rpm']

for l in cat_lst:
    df[l].fillna(df[l].mode()[0], inplace=True)
# Out:
# <ipython-input-192-4fde324ceec9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[l].fillna(df[l].mode()[0], inplace=True)
# <ipython-input-192-4fde324ceec9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[l].fillna(df[l].mode()[0], inplace=True)
# <ipython-input-192-4fde324ceec9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[l].fillna(df[l].mode()[0], inplace=True)
# <ipython-input-192-4fde324ceec9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[l].fillna(df[l].mode()[0], inplace=True)
# <ipython-input-192-4fde324ceec9>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[l].fillna(df[l].mode()[0], inplace=True)

# %% [markdown]
# ## Вопрос для Quiz
#
# Чему равно среднее значение `peak-rpm` до заполнения пропусков? Ответ округлите до целого числа.

# %%
round(df['peak-rpm'].dropna().astype('int').mean())
# Out:
# 5114

# %% [markdown]
# Пропуски в столбце `normalized-losses` предскажите при помощи линейной регрессии по признакам
# `symboling`, `wheel-base`, `length`, `width`, `height`, `curb-weight`, `engine-size`, `compression-ratio`, `city-mpg`, `highway-mpg` и заполните их предсказаниями

# %%
from sklearn.linear_model import LinearRegression

# your code here
lr = LinearRegression()

# %%
df_pred = df[['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg', 'normalized-losses']]

# %%
test_df = df_pred[df_pred['normalized-losses'].isnull() == True]
train_df = df_pred[df_pred['normalized-losses'].isnull() == False]
y = train_df['normalized-losses']

train_df.drop(['normalized-losses'], axis=1, inplace=True)
test_df.drop(['normalized-losses'], axis=1, inplace=True)
# Out:
# <ipython-input-196-9f35219ddce5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df.drop(['normalized-losses'], axis=1, inplace=True)
# <ipython-input-196-9f35219ddce5>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df.drop(['normalized-losses'], axis=1, inplace=True)

# %%
lr = LinearRegression()

lr.fit(train_df, y)

pred = lr.predict(test_df)

# %%
updated_df2 = df.copy()

indices = test_df.index.to_numpy()

updated_df2.loc[indices, 'normalized-losses'] = pred

# %%
# from sklearn.linear_model import LinearRegression

# X = df[df["normalized-losses"] != "?"][["symboling", "wheel-base", "length", "width", "height", "curb-weight", "engine-size", "compression-ratio", "city-mpg", "highway-mpg"]]
# y = df[df["normalized-losses"] != "?"]["normalized-losses"]

# model = LinearRegression()

# model.fit(X, y)

# df.loc[df["normalized-losses"] == "?", "normalized-losses"] = model.predict(df[df["normalized-losses"] == "?"][["symboling", "wheel-base", "length", "width", "height", "curb-weight", "engine-size", "compression-ratio", "city-mpg", "highway-mpg"]])

# %% [markdown]
# ## Вопрос для Quiz
#
# Чему равно предсказание линейной регрессии на первом пропущенном значении? Ответ округлите до целого числа.

# %%
pred[0]
# Out:
# 168.07249261651435

# %% [markdown]
# ## 2. Кодирование категориальных признаков

# %% [markdown]
# 1. Закодируйте бинарные признаки `fuel-type`, `aspiration`, `num-of-doors`, `engine-location` каждый отдельной колонкой, состоящей из 0 и 1.
# Единицей кодируйте самую частую категорию.

# %%
# your code here
updated_df2.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3        168.072493  alfa-romero       gas        std          two
# 1          3        168.072493  alfa-romero       gas        std          two
# 2          1        134.001799  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19    3.40              10.0        102      5500       24
# 4         mpfi  3.19    3.40               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
for l in ['fuel-type', 'aspiration', 'num-of-doors', 'engine-location']:
    updated_df2[l] = updated_df2[l].apply(lambda x: 1 if x == df[l].mode()[0] else 0)

# %% [markdown]
# 2. Вынесите в переменную `y` целевую переменную `price`, а все остальные колонки - в матрицу `X`.
#
# Закодируйте признаки `make`, `body-style`, `engine-type`, `fuel-system` при помощи LeaveOneOutEncoder.
#
# **Дальше все время работайте с объектами `X`, `y`.**

# %%
X = updated_df2.drop('price', axis=1)
y = updated_df2['price']

# %%
X.head()
# Out:
#    symboling normalized-losses         make  fuel-type  aspiration  \
# 0          3        168.072493  alfa-romero          1           1
# 1          3        168.072493  alfa-romero          1           1
# 2          1        134.001799  alfa-romero          1           1
# 3          2               164         audi          1           1
# 4          2               164         audi          1           1
#
#    num-of-doors   body-style drive-wheels  engine-location  wheel-base  ...  \
# 0             0  convertible          rwd                1        88.6  ...
# 1             0  convertible          rwd                1        88.6  ...
# 2             0    hatchback          rwd                1        94.5  ...
# 3             1        sedan          fwd                1        99.8  ...
# 4             1        sedan          4wd                1        99.4  ...
#
#    num-of-cylinders  engine-size  fuel-system  bore stroke compression-ratio  \
# 0              four          130         mpfi  3.47   2.68               9.0
# 1              four          130         mpfi  3.47   2.68               9.0
# 2               six          152         mpfi  2.68   3.47               9.0
# 3              four          109         mpfi  3.19   3.40              10.0
# 4              five          136         mpfi  3.19   3.40               8.0
#
#    horsepower peak-rpm city-mpg highway-mpg
# 0         111     5000       21          27
# 1         111     5000       21          27
# 2         154     5000       19          26
# 3         102     5500       24          30
# 4         115     5500       18          22
#
# [5 rows x 25 columns]

# %%
# !pip install category_encoders -q

# %%
from category_encoders.leave_one_out import LeaveOneOutEncoder

# your code here
loo_enc = LeaveOneOutEncoder()

updated_df3 = loo_enc.fit_transform(X[['make', 'body-style', 'engine-type', 'fuel-system']], y)

# %%
updated_df3.head()
# Out:
#       make    body-style   engine-type   fuel-system
# 0  16500.0  23569.600000  18536.545455  17650.307692
# 1  14997.5  22968.600000  18263.363636  17617.285714
# 2  14997.5   9859.791045  25814.916667  17617.285714
# 3  18641.0  14465.236559  11550.812500  17645.307692
# 4  17941.0  14427.602151  11526.506944  17606.846154

# %%
X[['make', 'body-style', 'engine-type', 'fuel-system']] = updated_df3

# %%
X['fuel-system']
# Out:
# 0      17650.307692
# 1      17617.285714
# 2      17617.285714
# 3      17645.307692
# 4      17606.846154
#            ...
# 200    17613.494505
# 201    17589.318681
# 202    17562.505495
# 203    15489.105263
# 204    17549.978022
# Name: fuel-system, Length: 201, dtype: float64

# %% [markdown]
# ## Вопрос для Quiz
#
# Чему равно среднее значение в столбце `body-style` после кодирования? Ответ округлите до целого числа.

# %%
updated_df3['body-style'].mean()
# Out:
# 13207.129353233831

# %% [markdown]
# 3. Закодируйте признак `drive-wheels` при помощи OHE из библиотеки category_encoders.

# %%
from category_encoders.one_hot import OneHotEncoder

# your code here

one_hot_enc = OneHotEncoder()

updated_df4 = one_hot_enc.fit_transform(X['drive-wheels'], Evgeny=1, Elena=0)

# %%
X.shape
# Out:
# (201, 25)

# %%
X = pd.concat([X, updated_df4], axis=1)

# %%
X.shape
# Out:
# (201, 28)

# %%
# X_new = ohe.fit_transform(X[['drive-wheels']])

# %%
X.head()
# Out:
#    symboling normalized-losses     make  fuel-type  aspiration  num-of-doors  \
# 0          3        168.072493  16500.0          1           1             0
# 1          3        168.072493  14997.5          1           1             0
# 2          1        134.001799  14997.5          1           1             0
# 3          2               164  18641.0          1           1             1
# 4          2               164  17941.0          1           1             1
#
#      body-style drive-wheels  engine-location  wheel-base  ...  bore  stroke  \
# 0  23569.600000          rwd                1        88.6  ...  3.47    2.68
# 1  22968.600000          rwd                1        88.6  ...  3.47    2.68
# 2   9859.791045          rwd                1        94.5  ...  2.68    3.47
# 3  14465.236559          fwd                1        99.8  ...  3.19    3.40
# 4  14427.602151          4wd                1        99.4  ...  3.19    3.40
#
#    compression-ratio  horsepower  peak-rpm city-mpg  highway-mpg  \
# 0                9.0         111      5000       21           27
# 1                9.0         111      5000       21           27
# 2                9.0         154      5000       19           26
# 3               10.0         102      5500       24           30
# 4                8.0         115      5500       18           22
#
#    drive-wheels_1 drive-wheels_2 drive-wheels_3
# 0               1              0              0
# 1               1              0              0
# 2               1              0              0
# 3               0              1              0
# 4               0              0              1
#
# [5 rows x 28 columns]

# %%
X.drop('drive-wheels_3', axis=1, inplace=True)
X.drop('drive-wheels', axis=1, inplace=True)

# %%
X.shape
# Out:
# (201, 26)

# %% [markdown]
# 4. В столбце `num-of-cylinders` категории упорядочены по смыслу. Закодируйте их подряд идущими числами, начиная с 1, согласно смыслу.
#
# Подряд идущими числами означает - 1, 2, 3 и так далее без пропусков.

# %%
from category_encoders.ordinal import OrdinalEncoder

# your code here
ord_enc = OrdinalEncoder()
X['num-of-cylinders'] = ord_enc.fit_transform(X['num-of-cylinders'])

# %% [markdown]
# ## Вопрос для Quiz
#
# Сколько столбцов получилось в матрице `X`?

# %%
X['normalized-losses'] = X['normalized-losses'].astype(float)
X['bore'] = X['bore'].astype(float)
X['stroke'] = X['stroke'].astype(float)
X['horsepower'] = X['horsepower'].astype(float)
X['peak-rpm'] = X['peak-rpm'].astype(float)

y = y.astype(float)

# %% [markdown]
# Разбейте данные на тренировочную и тестовую часть в пропорции 3 к 1, зафиксируйте random_state = 42.

# %%
from sklearn.model_selection import train_test_split

# your code here
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# Масштабируйте данные при помощи MinMaxScaler.
#
# Обучайте масштабирование на тренировочных данных, а потом примените и к трейну, и к тесту.

# %%
X.head()
# Out:
#    symboling  normalized-losses     make  fuel-type  aspiration  num-of-doors  \
# 0          3         168.072493  16500.0          1           1             0
# 1          3         168.072493  14997.5          1           1             0
# 2          1         134.001799  14997.5          1           1             0
# 3          2         164.000000  18641.0          1           1             1
# 4          2         164.000000  17941.0          1           1             1
#
#      body-style  engine-location  wheel-base  length  ...   fuel-system  bore  \
# 0  23569.600000                1        88.6   168.8  ...  17650.307692  3.47
# 1  22968.600000                1        88.6   168.8  ...  17617.285714  3.47
# 2   9859.791045                1        94.5   171.2  ...  17617.285714  2.68
# 3  14465.236559                1        99.8   176.6  ...  17645.307692  3.19
# 4  14427.602151                1        99.4   176.6  ...  17606.846154  3.19
#
#    stroke  compression-ratio  horsepower  peak-rpm  city-mpg  highway-mpg  \
# 0    2.68                9.0       111.0    5000.0        21           27
# 1    2.68                9.0       111.0    5000.0        21           27
# 2    3.47                9.0       154.0    5000.0        19           26
# 3    3.40               10.0       102.0    5500.0        24           30
# 4    3.40                8.0       115.0    5500.0        18           22
#
#    drive-wheels_1  drive-wheels_2
# 0               1               0
# 1               1               0
# 2               1               0
# 3               0               1
# 4               0               0
#
# [5 rows x 26 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# your code here
sc = MinMaxScaler()

X_train = pd.DataFrame(sc.fit_transform(X_train))
X_test = pd.DataFrame(sc.transform(X_test))

# %% [markdown]
# Обучите на тренировочных данных линейную регрессию, сделайте предсказание на тесте и вычислите значение $R^2$ на тестовых данных.

# %%
# your code here

lr = LinearRegression()

lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)

# %% [markdown]
# ## Вопрос для Quiz
#
# Чему равно значение $R^2$ на тестовых данных? Ответ округлите до сотых.

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9128282823425578
